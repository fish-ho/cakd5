# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Q. titanic 데이터셋에서 age, fare 2개 열을 선택하여 데이터프레임 df를 만드세요

# %%
titanic = sns.load_dataset('titanic')
# df = titanic.groupby(['age','fare'])
df=titanic.loc[:,['age','fare']]
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Q. 10을 더하는 함수 add_10 과 두 객체의 합 add_two_obj 함수를 정의한 후 결과값이 각각 20과 20을 출력하세요.

# %%
def add_10(a):
    return a+10
def add_two_obj(a,b):
    
    return a+b

a=int(input('숫자 입력 : '))
b=int(input('숫자 입력2 : '))

print(add_10(a))
print(add_two_obj(a,b))
# Out:
# 숫자 입력 : 10
# 숫자 입력2 : 10
# 20
# 20

# %% [markdown]
# ### Q. 10을 곱하는 사용자 함수와 두 객체의 나눗셈을 수행하는 사용자 함수를 정의한 후 결과값이 각각 200과 10을 출력하세요.

# %%
def mul_10(a):    
    return a*10
def div(a,b):
    
    return a/b

a=int(input('숫자 입력 : '))
b=int(input('숫자 입력2 : '))
print(mul_10(a))
print(div(a,b))
# Out:
# 숫자 입력 : 20
# 숫자 입력2 : 10
# None
# None

# %% [markdown]
# ### Q.df_age 에 add_10 함수를 적용해서 출력하세요.

# %%
df_age=pd.DataFrame(df.age)
df_age.apply(add_10)
# Out:
#       age
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# ..    ...
# 886  37.0
# 887  29.0
# 888   NaN
# 889  36.0
# 890  42.0
#
# [891 rows x 1 columns]

# %% [markdown]
# ### Q. 시리즈 객체 + 숫자를 연산하는 방식으로 df.age에 10을 더한 후 sr2에 저장하고 출력하세요.

# %%
sr2=df.age+10
sr2
# Out:
# 0      32.0
# 1      48.0
# 2      36.0
# 3      45.0
# 4      45.0
#        ...
# 886    37.0
# 887    29.0
# 888     NaN
# 889    36.0
# 890    42.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# ### Q. 람다 함수를 활용해서 위와 같은 연산을 수행하고 결과를 sr3로 출력하세요.

# %%
sr3=df.age.apply(lambda x: x+10)
sr3
# Out:
# 0      32.0
# 1      48.0
# 2      36.0
# 3      45.0
# 4      45.0
#        ...
# 886    37.0
# 887    29.0
# 888     NaN
# 889    36.0
# 890    42.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# ### Q. df의 'age', 'fare' 칼럼에 10을 더하는 사용자 함수를 정의하고 applymap()으로 각 사용자 함수를 매핑한 후 출력하세요.

# %%
def ad_10(x):
    return x+10
df.applymap(ad_10)
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Q. df_map의 [0,0]을 NaN으로 변경한 후 missing_value 함수를 적용해서 불린 시리즈를 반환하세요.

# %%
df_map=df.copy()
df_map.iloc[0,0]=np.nan
df_map

def missing_value(x):
    return x.isnull()
    
missing_value(df_map)
# df_map.isnull()
# Out:
#        age   fare
# 0     True  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Q. titanic 데이터셋을 seaborn에서 로딩한 후 블린 인덱싱을 이용하여 아래 사항들을 수행하세요.
# - 나이가 10대(10~19세)인 승객만 따로 선택
# - 나이가 10세 미만(0~9세)이고 여성인 승객만 따로 선택
# - 나이가 10세 미만(0~9세) 또는 60세 이상인 승객의 age, sex, alone 열만 선택

# %%
# 나이가 10대(10~19세)인 승객만 따로 선택
df1 = sns.load_dataset('titanic')
teen = df1.loc[(df['age']>=10) & (df1['age']<20)]
teen

# 나이가 10세 미만(0~9세)이고 여성인 승객만 따로 선택
child = df1.loc[(df['age'] < 10) & (df1['sex']=='female')]
child

# 나이가 10세 미만(0~9세) 또는 60세 이상인 승객의 age, sex, alone 열만 선택
weak = df1.loc[(df['age'] < 10) | (df1['age'] >=60), ['age','sex','alone']]
weak
# Out:
#        age     sex  alone
# 7     2.00    male  False
# 10    4.00  female  False
# 16    2.00    male  False
# 24    8.00  female  False
# 33   66.00    male   True
# ..     ...     ...    ...
# 831   0.83    male  False
# 850   4.00    male  False
# 851  74.00    male   True
# 852   9.00  female  False
# 869   4.00    male  False
#
# [88 rows x 3 columns]

# %% [markdown]
# ## Q. 나이가 10세 미만(0~9세) 또는 60세 이상인 승객의 alone 열만 선택한 후 값을 True로 변경하세요

# %%
weak1 = df1.loc[(df1['age'] < 10) | (df1['age'] >=60)]
weak1['alone']=True
weak1[['alone']]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_8900/1760450185.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weak1['alone']=True
#      alone
# 7     True
# 10    True
# 16    True
# 24    True
# 33    True
# ..     ...
# 831   True
# 850   True
# 851   True
# 852   True
# 869   True
#
# [88 rows x 1 columns]

# %% [markdown]
# ### Q. 최대값 - 최소값을 반환하는 사용자 함수를 min_max로 정의하고 age, fare 열로 구성되는 타이타닉 데이터프레임df 에 적용하여 결과와 자료형을 출력하세요. source : titanic = sns.load_dataset('titanic')

# %%
def min_max(a):
    return a.max()-a.min()
print(min_max(df),type(min_max(df)))
# Out:
# age      79.5800
# fare    512.3292
# dtype: float64 <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Q. df 에서 'age' 칼럼과 'fare'칼럼을 더한 가격을 리턴하는 사용자 함수를 정의한 후 df['add'] 변수를 생성하여 출력하세요.(lambda 함수 사용)

# %%
# 수정 요 lambda 사용
def addd():
    return df1['age']+df1['fare']
addd()
df1['add']=addd()
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone       add
# 0      man        True  NaN  Southampton    no  False   29.2500
# 1    woman       False    C    Cherbourg   yes  False  109.2833
# 2    woman       False  NaN  Southampton   yes   True   33.9250
# 3    woman       False    C  Southampton   yes  False   88.1000
# 4      man        True  NaN  Southampton    no   True   43.0500
# ..     ...         ...  ...          ...   ...    ...       ...
# 886    man        True  NaN  Southampton    no   True   40.0000
# 887  woman       False    B  Southampton   yes   True   49.0000
# 888  woman       False  NaN  Southampton    no  False       NaN
# 889    man        True    C    Cherbourg   yes   True   56.0000
# 890    man        True  NaN   Queenstown    no   True   39.7500
#
# [891 rows x 16 columns]

# %%
def df1_add(x,y):
    return x+y
df1['add'] = df1.apply(lambda x: df1_add(x['age'],x['fare']),axis=1)
# df1['add'] = df1.apply(lambda x,y: df1_add(x,y))
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone       add
# 0      man        True  NaN  Southampton    no  False   29.2500
# 1    woman       False    C    Cherbourg   yes  False  109.2833
# 2    woman       False  NaN  Southampton   yes   True   33.9250
# 3    woman       False    C  Southampton   yes  False   88.1000
# 4      man        True  NaN  Southampton    no   True   43.0500
# ..     ...         ...  ...          ...   ...    ...       ...
# 886    man        True  NaN  Southampton    no   True   40.0000
# 887  woman       False    B  Southampton   yes   True   49.0000
# 888  woman       False  NaN  Southampton    no  False       NaN
# 889    man        True    C    Cherbourg   yes   True   56.0000
# 890    man        True  NaN   Queenstown    no   True   39.7500
#
# [891 rows x 16 columns]

# %% [markdown]
# ### Q. 'age', 'fare' 두개 칼럼으로 구성되는 titanic 데이터프레임에서 [0,1]의 값을 NaN을 변경한 후 df 이름으로 출력하세요.

# %%
df3 = titanic.loc[:,['age','fare']]
df3.iloc[0,1]=np.nan
df3
# Out:
#       age     fare
# 0    22.0      NaN
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Q. 각 열의 NaN 찾기, 각 열의 NaN 개수 반환, 데이터프레임의 총 NaN 개수를 반환하는 사용자 함수를 정의한 후 df.pipe 메소드로 함수 매핑한 결과를 모두 출력하세요.

# %%
df4=titanic.copy()
a=list(df4.columns)
for i in a:
    x=df4[i].isnull().sum()
    print(f'{i}열',x)
# Out:
# survived열 0
# pclass열 0
# sex열 0
# age열 177
# sibsp열 0
# parch열 0
# fare열 0
# embarked열 2
# class열 0
# who열 0
# adult_male열 0
# deck열 688
# embark_town열 2
# alive열 0
# alone열 0

# %%
df4=titanic.copy()
a=list(df4.columns)
def find_nan():
    return df4.isnull()

def return_nan(): 
    for i in a:
        t=df4[i].isnull().sum()
        print(t)
#     return printt 
    
def total_nan():
    return df4.isnull().sum()

return_nan()
# Out:
# 0
# 0
# 0
# 177
# 0
# 0
# 0
# 2
# 0
# 0
# 0
# 688
# 2
# 0
# 0

# %% [markdown]
# ### Q. 타이타닉 df의 열 순서를 아래와 같이 재구성하고 출력하세요
# * 열 선택 : ['pclass', 'sex', 'age', 'survived'].
# * 열 이름의 리스트 만들기
# * 열 이름을 알파벳 순으로 정렬하기
# * 열 이름을 기존 순서의 정반대 역순으로 정렬하기
# * 열 이름을 사용자가 정의한 임의의 순서로 재배치하기
